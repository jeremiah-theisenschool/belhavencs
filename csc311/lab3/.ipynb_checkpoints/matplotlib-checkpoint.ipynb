# %%
import pandas as pd

data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/tips.csv')

data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data['day'], data['tip'])
plt.title('Scatter Plot')
plt.xlabel('Day of Week')
plt.ylabel('Tips')
plt.show()

# %%
plt.scatter(data['day'], data['tip'], c=data['size'], s=data['total_bill'])
plt.title('Scatter Plot')
plt.xlabel('Day of Week')
plt.ylabel('Tips')
# Out:
# Text(0, 0.5, 'Tips')

# %%
plt.plot(data['tip'])
plt.plot(data['size'])
plt.title('Line Plot')
plt.xlabel('Number of response')
plt.ylabel('Tips')
# Out:
# Text(0, 0.5, 'Tips')

# %%
plt.bar(data['day'], data['tip'])
plt.title('Bar Chart')
plt.xlabel('Day of Week')
plt.ylabel('Tips')
# Out:
# Text(0, 0.5, 'Tips')

# %%
plt.hist(data['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
sns.lineplot(x='sex', y='total_bill', data=data)
plt.title('Line Plot - Title From Matplotlib')
# Out:
# Text(0.5, 1.0, 'Line Plot - Title From Matplotlib')

# %%
sns.scatterplot(x='day', y='tip', data=data)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.scatterplot(x='day', y='tip', data=data, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.lineplot(x='day', y='tip', data=data)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.barplot(x='day', y='tip', data=data, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.histplot(x='total_bill', data=data,  hue='sex', kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
import plotly.express as px
fig = px.scatter(data, x='day', y='tip', color='sex')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24700\2409967012.py in <module>
#       1 import plotly.express as px
# ----> 2 fig = px.scatter(data, x='day', y='tip', color='sex')
#       3 fig.show()
#
# NameError: name 'data' is not defined

# %%
fig = px.line(data, y='tip', color='sex')
fig.show()

# %%
fig = px.bar(data, x='day', y='tip', color='sex')
fig.show()

# %%
fig = px.histogram(data, x='total_bill', color='size')
fig.show()

# %%
import plotly.graph_objects as px
plot = px.Figure(data=[px.Scatter(x=data['day'], y=data['tip'], mode='markers')])
#dropdown
plot.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                dict(
                    args=["type", "scatter"],
                    label ="Scatter Plot",
                    method = "restyle"
                )

                ,

                dict(
                    args=["type", "bar"],
                    label='Bar Chart',
                    method='restyle'

                )
            ])
        )
    ]

)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24700\48507173.py in <module>
#       1 import plotly.graph_objects as px
# ----> 2 plot = px.Figure(data=[px.Scatter(x=data['day'], y=data['tip'], mode='markers')])
#       3 #dropdown
#       4 plot.update_layout(
#       5     updatemenus=[
#
# NameError: name 'data' is not defined
